# %%
years = list(range(1992,2023))

# %%
url_template = "https://www.basketball-reference.com/awards/awards_{}.html"

# %%
import requests

for year in years: 
    url = url_template.format(year) 
    data = requests.get(url)

    with open("NBA_Project/mvps/{}.html".format(year), "w+") as file:
        file.write(data.text)

# %%
from bs4 import BeauitfulSoup

# %%
with open ("mvp/1992.html") as file: 
    page = file.read()

# %%
soup = BeautifulSoup(page, "html.parser")

# %%
soup.find("tr", class="over_header").decompose()

# %%
mvp_tables = soup.find(id = "mvp")

# %%
import pandas as pd

# %%
mvp_1992 = pd.read_html(str(mvp_tables))

# %%
mvp_1992
